# %%
# script to evaluate the performance of one agent on one crypto
# write a python script instead of the Jupyter Notebook will be easier
import sys
sys.path.append('/home/pop/conda/lib/python3.8/site-packages')
print(sys.path)

#importation of modules
import numpy as np
import math
import gym
from finrl_meta.env_crypto_trading.env_multiple_crypto import CryptoEnv
from finrl.plot import backtest_stats
from finrl import config
from agents.stablebaselines3_models import DRLAgent as DRLAgent_sb3
from agents.rllib_models import DRLAgent as DRLAgent_rllib
from agents.elegantrl_models import DRLAgent as DRLAgent_erl

import pandas as pd
from plot2 import get_baseline, get_daily_return, backtest_plot

from finrl_meta.data_processor import DataProcessor

# ignore pandas warning 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from test import test
from train import train
from cryptoenv import CryptoEnv


TICKER_LIST = ['BTCUSDT','ETHUSDT','ADAUSDT','BNBUSDT','XRPUSDT',
                'SOLUSDT','DOTUSDT', 'DOGEUSDT','AVAXUSDT','UNIUSDT']
TICKER = [TICKER_LIST[0]]
print(TICKER)

TRAIN_START_DATE = '2021-10-01'
TRAIN_END_DATE = '2022-02-26'

TEST_START_DATE = '2022-03-01'
TEST_END_DATE = '2022-04-01'

time_interval = '5m'

env = CryptoEnv


INDICATORS = ['macd', 'rsi', 'cci', 'dx'] #self-defined technical indicator list is NOT supported yet

ERL_PARAMS = {"learning_rate": 2**-15,"batch_size": 2**11,
                "gamma": 0.99, "seed":312,"net_dimension": 2**9, 
                "target_step": 5000, "eval_gap": 30, "eval_times": 1}

RLLIB_PARAMS = {"lr": 2**-15,"train_batch_size": 2**11,
                "gamma": 0.99, "num_workers": 0,
                "horizon": 1e10, 
               "disable_env_checkin": True}


# training of the agent

print('----------Training-----------------')

train(start_date=TRAIN_START_DATE, 
       end_date=TRAIN_END_DATE,
       ticker_list=TICKER,    #only one ticker for the moment (deal with get_baseline for multiple ticker)
       data_source='binance',
       time_interval=time_interval, 
       technical_indicator_list=INDICATORS,
       drl_lib='elegantrl', 
       env=env, 
       model_name='ppo', 
       cwd='./test_ppo_el',
       erl_params=ERL_PARAMS,
       break_step=5e4,
       if_vix=False
       )

print('----------End Training-----------------')

#testing of the agent

print('----------- Testing -----------------')


#with rllib have to check the path sometimes, have to fix it to make it work properly

account_value_erl = test(start_date = TEST_START_DATE, 
                        end_date = TEST_END_DATE,
                        ticker_list = TICKER, 
                        data_source = 'binance',
                        time_interval= time_interval, 
                        technical_indicator_list= INDICATORS,
                        drl_lib='elegantrl', 
                        env=env, 
                        model_name='ppo', 
                        cwd='./test_ppo_el', 
                        net_dimension = 2**9, 
                        if_vix=False
                        )

print('--------- End Testing ------------------')


baseline_df = get_baseline(TICKER, TEST_START_DATE, TEST_END_DATE, time_interval)
account_value_erl_pd = pd.DataFrame({'date':baseline_df.date,'account_value':account_value_erl})

backtest_plot(account_value_erl_pd, 
             baseline_ticker = TICKER, 
             baseline_start = TEST_START_DATE,
             baseline_end = TEST_END_DATE)
# Out:
# ['/home/pop/.local/lib/python3.8/site-packages/ray/thirdparty_files', '/home/pop/.local/lib/python3.8/site-packages/ray/pickle5_files', '/home/pop/Documents/Code/RTML/Project/finRL/FinRL-Meta', '', '/home/pop/conda/lib/python3.8/site-packages', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '/home/pop/.local/lib/python3.8/site-packages', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/home/pop/.local/lib/python3.8/site-packages/IPython/extensions', '/home/pop/.ipython', '/home/pop/conda/lib/python3.8/site-packages', '/home/pop/conda/lib/python3.8/site-packages']
# ['BTCUSDT']
# ----------Training-----------------
# binance successfully connected
# 2021-10-01 2022-02-26
# 10
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# | Arguments Remove cwd: ./test_ppo_el
# ################################################################################
# ID     Step    maxR |    avgR   stdR   avgS  stdS |    expR   objC   etc.
# 0  3.11e+04    1.00 |
# 0  3.11e+04    1.00 |    1.00    0.0  31121     0 |   -0.00   0.00   0.02  -0.50
# 0  6.22e+04    1.00 |    0.95    0.0  31121     0 |   -0.00   0.01  -0.00  -0.51
# | UsedTime: 514 | SavedDir: ./test_ppo_el
# ----------End Training-----------------
# ----------- Testing -----------------
# binance successfully connected
# 2022-03-01 2022-04-01
# 10
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# price_array:  6701
# /home/pop/Documents/Code/RTML/Project/finRL/FinRL-Meta/agents/elegantrl_models.py:111: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   s_tensor = _torch.as_tensor((state,), device=device)
# Test Finished!
# episode_return 1.0
# --------- End Testing ------------------
# binance successfully connected
# 2022-03-01 2022-04-01
# 10
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# binance successfully connected
# Using cached file ./cache/BTCUSDT_binance_2022-03-01_2022-04-01_5m.pickle
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# /home/pop/.local/lib/python3.8/site-packages/empyrical/stats.py:710: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(
# /home/pop/.local/lib/python3.8/site-packages/empyrical/stats.py:799: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(average_annual_return, annualized_downside_risk, out=out)
# /home/pop/.local/lib/python3.8/site-packages/empyrical/stats.py:1527: RuntimeWarning: invalid value encountered in double_scalars
#   return np.abs(np.percentile(returns, 95)) / \
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2022-03-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-03-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>319</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.00</td>
#       <td>2022-03-01</td>
#       <td>2022-03-01</td>
#       <td>2022-03-01</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.00%</td>
#       <td>0.00%</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# script to evaluate the performance of one agent on one crypto
# write a python script instead of the Jupyter Notebook will be easier
import sys
sys.path.append('/home/pop/conda/lib/python3.8/site-packages')
print(sys.path)

#importation of modules
import numpy as np
import math
import gym
from finrl_meta.env_crypto_trading.env_multiple_crypto import CryptoEnv
from finrl.plot import backtest_stats
from finrl import config
from agents.stablebaselines3_models import DRLAgent as DRLAgent_sb3
from agents.rllib_models import DRLAgent as DRLAgent_rllib
from agents.elegantrl_models import DRLAgent as DRLAgent_erl

import pandas as pd
from plot2 import get_baseline, get_daily_return, backtest_plot

from finrl_meta.data_processor import DataProcessor

# ignore pandas warning 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from test import test
from train import train
from cryptoenv import CryptoEnv





TICKER_LIST = ['BTCUSDT','ETHUSDT','ADAUSDT','BNBUSDT','XRPUSDT',
                'SOLUSDT','DOTUSDT', 'DOGEUSDT','AVAXUSDT','UNIUSDT']
TICKER = [TICKER_LIST[0]]
print(TICKER)

TRAIN_START_DATE = '2021-09-01'
TRAIN_END_DATE = '2021-09-02'

TEST_START_DATE = '2021-09-21'
TEST_END_DATE = '2021-09-30'
time_interval = '5m'

env = CryptoEnv


INDICATORS = ['macd', 'rsi', 'cci', 'dx'] #self-defined technical indicator list is NOT supported yet

ERL_PARAMS = {"learning_rate": 2**-15,"batch_size": 2**11,
                "gamma": 0.99, "seed":312,"net_dimension": 2**9, 
                "target_step": 5000, "eval_gap": 30, "eval_times": 1}

RLLIB_PARAMS = {"lr": 2**-15,"train_batch_size": 2**11,
                "gamma": 0.99, "num_workers": 0,
                "horizon": 1e10, 
               "disable_env_checkin": True}


# training of the agent

print('----------Training-----------------')

# train(start_date=TRAIN_START_DATE, 
#        end_date=TRAIN_END_DATE,
#        ticker_list=TICKER,    #only one ticker for the moment (deal with get_baseline for multiple ticker)
#        data_source='binance',
#        time_interval=time_interval, 
#        technical_indicator_list=INDICATORS,
#        drl_lib='elegantrl', 
#        env=env, 
#        model_name='ddpg', 
#        cwd='./test_ddpg_el',
#        erl_params=ERL_PARAMS,
#        break_step=5e4,
#        if_vix=False
#        )

print('----------End Training-----------------')

#testing of the agent

print('----------- Testing -----------------')


#with rllib have to check the path sometimes, have to fix it to make it work properly

account_value_erl = test(start_date = TEST_START_DATE, 
                        end_date = TEST_END_DATE,
                        ticker_list = TICKER, 
                        data_source = 'binance',
                        time_interval= time_interval, 
                        technical_indicator_list= INDICATORS,
                        drl_lib='elegantrl', 
                        env=env, 
                        model_name='ddpg', 
                        cwd='./test_ddpg_el', 
                        net_dimension = 2**9, 
                        if_vix=False
                        )

print('--------- End Testing ------------------')


baseline_df = get_baseline(TICKER, TEST_START_DATE, TEST_END_DATE, time_interval)
account_value_erl_pd = pd.DataFrame({'date':baseline_df.date,'account_value':account_value_erl})

backtest_plot(account_value_erl_pd, 
             baseline_ticker = TICKER, 
             baseline_start = TEST_START_DATE,
             baseline_end = TEST_END_DATE)
# Out:
# ['/home/pop/.local/lib/python3.8/site-packages/ray/thirdparty_files', '/home/pop/.local/lib/python3.8/site-packages/ray/pickle5_files', '/home/pop/Documents/Code/RTML/Project/finRL/FinRL-Meta', '', '/home/pop/conda/lib/python3.8/site-packages', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '/home/pop/.local/lib/python3.8/site-packages', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/home/pop/.local/lib/python3.8/site-packages/IPython/extensions', '/home/pop/.ipython', '/home/pop/conda/lib/python3.8/site-packages', '/home/pop/conda/lib/python3.8/site-packages', '/home/pop/conda/lib/python3.8/site-packages']
# ['BTCUSDT']
# ----------Training-----------------
# ----------End Training-----------------
# ----------- Testing -----------------
# binance successfully connected
# 2021-09-21 2021-09-30
# 10
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# price_array:  1998
# Test Finished!
# episode_return 0.9773778631278315
# --------- End Testing ------------------
# binance successfully connected
# Using cached file ./cache/BTCUSDT_binance_2021-09-21_2021-09-30_5m.pickle
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# binance successfully connected
# Using cached file ./cache/BTCUSDT_binance_2021-09-21_2021-09-30_5m.pickle
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-09-21</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-09-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>95</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-0.288%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-2.262%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>3.012%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.08</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.04</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-6.472%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.11</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.01</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.38%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.62</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6.47</td>
#       <td>2021-09-24</td>
#       <td>2021-09-26</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.56</td>
#       <td>2021-09-21</td>
#       <td>2021-09-22</td>
#       <td>2021-09-22</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.94</td>
#       <td>2021-09-21</td>
#       <td>2021-09-21</td>
#       <td>2021-09-21</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.41</td>
#       <td>2021-09-23</td>
#       <td>2021-09-23</td>
#       <td>2021-09-24</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.37</td>
#       <td>2021-09-23</td>
#       <td>2021-09-23</td>
#       <td>2021-09-23</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.00%</td>
#       <td>-3.02%</td>
#       <td>2.24%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# script to evaluate the performance of one agent on one crypto
# write a python script instead of the Jupyter Notebook will be easier
import sys
sys.path.append('/home/pop/conda/lib/python3.8/site-packages')
print(sys.path)

#importation of modules
import numpy as np
import math
import gym
from finrl_meta.env_crypto_trading.env_multiple_crypto import CryptoEnv
from finrl.plot import backtest_stats
from finrl import config
from agents.stablebaselines3_models import DRLAgent as DRLAgent_sb3
from agents.rllib_models import DRLAgent as DRLAgent_rllib
from agents.elegantrl_models import DRLAgent as DRLAgent_erl

import pandas as pd
from plot2 import get_baseline, get_daily_return, backtest_plot

from finrl_meta.data_processor import DataProcessor

# ignore pandas warning 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from test import test
from train import train
from cryptoenv import CryptoEnv





TICKER_LIST = ['BTCUSDT','ETHUSDT','ADAUSDT','BNBUSDT','XRPUSDT',
                'SOLUSDT','DOTUSDT', 'DOGEUSDT','AVAXUSDT','UNIUSDT']
TICKER = [TICKER_LIST[0]]
print(TICKER)

TRAIN_START_DATE = '2021-09-01'
TRAIN_END_DATE = '2021-09-02'

TEST_START_DATE = '2021-09-21'
TEST_END_DATE = '2021-09-30'
time_interval = '5m'

env = CryptoEnv


INDICATORS = ['macd', 'rsi', 'cci', 'dx'] #self-defined technical indicator list is NOT supported yet

ERL_PARAMS = {"learning_rate": 2**-15,"batch_size": 2**11,
                "gamma": 0.99, "seed":312,"net_dimension": 2**9, 
                "target_step": 5000, "eval_gap": 30, "eval_times": 1}

RLLIB_PARAMS = {"lr": 2**-15,"train_batch_size": 2**11,
                "gamma": 0.99, "num_workers": 0,
                "horizon": 1e10, 
               "disable_env_checkin": True}


# training of the agent

print('----------Training-----------------')

train(start_date=TRAIN_START_DATE, 
       end_date=TRAIN_END_DATE,
       ticker_list=TICKER,    #only one ticker for the moment (deal with get_baseline for multiple ticker)
       data_source='binance',
       time_interval=time_interval, 
       technical_indicator_list=INDICATORS,
       drl_lib='elegantrl', 
       env=env, 
       model_name='td3', 
       cwd='./test_td3_el',
       erl_params=ERL_PARAMS,
       break_step=5e4,
       if_vix=False
       )

print('----------End Training-----------------')

#testing of the agent

print('----------- Testing -----------------')


#with rllib have to check the path sometimes, have to fix it to make it work properly

account_value_erl = test(start_date = TEST_START_DATE, 
                        end_date = TEST_END_DATE,
                        ticker_list = TICKER, 
                        data_source = 'binance',
                        time_interval= time_interval, 
                        technical_indicator_list= INDICATORS,
                        drl_lib='elegantrl', 
                        env=env, 
                        model_name='td3', 
                        cwd='./test_td3_el', 
                        net_dimension = 2**9, 
                        if_vix=False
                        )

print('--------- End Testing ------------------')


baseline_df = get_baseline(TICKER, TEST_START_DATE, TEST_END_DATE, time_interval)
account_value_erl_pd = pd.DataFrame({'date':baseline_df.date,'account_value':account_value_erl})

backtest_plot(account_value_erl_pd, 
             baseline_ticker = TICKER, 
             baseline_start = TEST_START_DATE,
             baseline_end = TEST_END_DATE)
# Out:
# ['/home/pop/.local/lib/python3.8/site-packages/ray/thirdparty_files', '/home/pop/.local/lib/python3.8/site-packages/ray/pickle5_files', '/home/pop/Documents/Code/RTML/Project/finRL/FinRL-Meta', '', '/home/pop/conda/lib/python3.8/site-packages', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '/home/pop/.local/lib/python3.8/site-packages', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/home/pop/.local/lib/python3.8/site-packages/IPython/extensions', '/home/pop/.ipython', '/home/pop/conda/lib/python3.8/site-packages', '/home/pop/conda/lib/python3.8/site-packages', '/home/pop/conda/lib/python3.8/site-packages', '/home/pop/conda/lib/python3.8/site-packages']
# ['BTCUSDT']
# ----------Training-----------------
# binance successfully connected
# 2021-09-01 2021-09-02
# 10
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2830/3405562787.py in <module>
#      64 print('----------Training-----------------')
#      65
# ---> 66 train(start_date=TRAIN_START_DATE,
#      67        end_date=TRAIN_END_DATE,
#      68        ticker_list=TICKER,    #only one ticker for the moment (deal with get_baseline for multiple ticker)
#
# ~/Documents/Code/RTML/Project/finRL/FinRL-Meta/train.py in train(start_date, end_date, ticker_list, data_source, time_interval, technical_indicator_list, drl_lib, env, model_name, if_vix, **kwargs)
#      10     # process data using unified data processor
#      11     dp = DataProcessor(data_source, start_date, end_date, time_interval, **kwargs)
# ---> 12     price_array, tech_array, turbulence_array = dp.run(ticker_list,
#      13                                                        technical_indicator_list,
#      14                                                        if_vix)
#
# ~/Documents/Code/RTML/Project/finRL/FinRL-Meta/finrl_meta/data_processor.py in run(self, ticker_list, technical_indicator_list, if_vix, cache, select_stockstats_talib)
#     128
#     129
# --> 130         self.add_technical_indicator(technical_indicator_list, select_stockstats_talib)
#     131         if if_vix:
#     132             self.add_vix()
#
# ~/Documents/Code/RTML/Project/finRL/FinRL-Meta/finrl_meta/data_processor.py in add_technical_indicator(self, tech_indicator_list, select_stockstats_talib)
#      75     def add_technical_indicator(self, tech_indicator_list: List[str], select_stockstats_talib: int = 0):
#      76         self.tech_indicator_list = tech_indicator_list
# ---> 77         self.processor.add_technical_indicator(tech_indicator_list, select_stockstats_talib)
#      78         self.dataframe = self.processor.dataframe
#      79
#
# ~/Documents/Code/RTML/Project/finRL/FinRL-Meta/finrl_meta/data_processors/_base.py in add_technical_indicator(self, tech_indicator_list, select_stockstats_talib)
#     121                             "time"
#     122                         ].to_list()
# --> 123                         indicator_df = indicator_df.append(
#     124                             temp_indicator, ignore_index=True
#     125                         )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    9018             "Use pandas.concat instead.",
#    9019             FutureWarning,
# -> 9020             stacklevel=find_stack_level(),
#    9021         )
#    9022
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_exceptions.py in find_stack_level()
#      30     (tests notwithstanding).
#      31     """
# ---> 32     stack = inspect.stack()
#      33
#      34     import pandas as pd
#
# /usr/lib/python3.8/inspect.py in stack(context)
#    1524 def stack(context=1):
#    1525     """Return a list of records for the stack above the caller's frame."""
# -> 1526     return getouterframes(sys._getframe(1), context)
#    1527
#    1528 def trace(context=1):
#
# /usr/lib/python3.8/inspect.py in getouterframes(frame, context)
#    1501     framelist = []
#    1502     while frame:
# -> 1503         frameinfo = (frame,) + getframeinfo(frame, context)
#    1504         framelist.append(FrameInfo(*frameinfo))
#    1505         frame = frame.f_back
#
# /usr/lib/python3.8/inspect.py in getframeinfo(frame, context)
#    1475         start = lineno - 1 - context//2
#    1476         try:
# -> 1477             lines, lnum = findsource(frame)
#    1478         except OSError:
#    1479             lines = index = None
#
# /usr/lib/python3.8/inspect.py in findsource(object)
#     778     is raised if the source code cannot be retrieved."""
#     779
# --> 780     file = getsourcefile(object)
#     781     if file:
#     782         # Invalidate cache if needed.
#
# /usr/lib/python3.8/inspect.py in getsourcefile(object)
#     706         return filename
#     707     # only return a non-existent filename if the module has a PEP 302 loader
# --> 708     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#     709         return filename
#     710     # or it is in the linecache
#
# /usr/lib/python3.8/inspect.py in getmodule(object, _filename)
#     742     # Update the filename to module name cache and check yet again
#     743     # Copy sys.modules in order to cope with changes while iterating
# --> 744     for modname, module in sys.modules.copy().items():
#     745         if ismodule(module) and hasattr(module, '__file__'):
#     746             f = module.__file__
#
# KeyboardInterrupt:

# %%
# script to evaluate the performance of one agent on one crypto
# write a python script instead of the Jupyter Notebook will be easier
import sys
sys.path.append('/home/pop/conda/lib/python3.8/site-packages')
print(sys.path)

#importation of modules
import numpy as np
import math
import gym
from finrl_meta.env_crypto_trading.env_multiple_crypto import CryptoEnv
from finrl.plot import backtest_stats
from finrl import config
from agents.stablebaselines3_models import DRLAgent as DRLAgent_sb3
from agents.rllib_models import DRLAgent as DRLAgent_rllib
from agents.elegantrl_models import DRLAgent as DRLAgent_erl

import pandas as pd
from plot2 import get_baseline, get_daily_return, backtest_plot

from finrl_meta.data_processor import DataProcessor

# ignore pandas warning 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from test import test
from train import train
from cryptoenv import CryptoEnv





TICKER_LIST = ['BTCUSDT','ETHUSDT','ADAUSDT','BNBUSDT','XRPUSDT',
                'SOLUSDT','DOTUSDT', 'DOGEUSDT','AVAXUSDT','UNIUSDT']
TICKER = [TICKER_LIST[0]]
print(TICKER)

TRAIN_START_DATE = '2021-09-01'
TRAIN_END_DATE = '2021-09-02'

TEST_START_DATE = '2021-09-21'
TEST_END_DATE = '2021-09-30'
time_interval = '5m'

env = CryptoEnv


INDICATORS = ['macd', 'rsi', 'cci', 'dx'] #self-defined technical indicator list is NOT supported yet

ERL_PARAMS = {"learning_rate": 2**-15,"batch_size": 2**11,
                "gamma": 0.99, "seed":312,"net_dimension": 2**9, 
                "target_step": 5000, "eval_gap": 30, "eval_times": 1}

RLLIB_PARAMS = {"lr": 2**-15,"train_batch_size": 2**11,
                "gamma": 0.99, "num_workers": 0,
                "horizon": 1e10, 
               "disable_env_checkin": True}


# training of the agent

print('----------Training-----------------')

train(start_date=TRAIN_START_DATE, 
       end_date=TRAIN_END_DATE,
       ticker_list=TICKER,    #only one ticker for the moment (deal with get_baseline for multiple ticker)
       data_source='binance',
       time_interval=time_interval, 
       technical_indicator_list=INDICATORS,
       drl_lib='elegantrl', 
       env=env, 
       model_name='sac', 
       cwd='./test_sac_el',
       erl_params=ERL_PARAMS,
       break_step=5e4,
       if_vix=False
       )

print('----------End Training-----------------')

#testing of the agent

print('----------- Testing -----------------')


#with rllib have to check the path sometimes, have to fix it to make it work properly

account_value_erl = test(start_date = TEST_START_DATE, 
                        end_date = TEST_END_DATE,
                        ticker_list = TICKER, 
                        data_source = 'binance',
                        time_interval= time_interval, 
                        technical_indicator_list= INDICATORS,
                        drl_lib='elegantrl', 
                        env=env, 
                        model_name='sac', 
                        cwd='./test_sac_el', 
                        net_dimension = 2**9, 
                        if_vix=False
                        )

print('--------- End Testing ------------------')


baseline_df = get_baseline(TICKER, TEST_START_DATE, TEST_END_DATE, time_interval)
account_value_erl_pd = pd.DataFrame({'date':baseline_df.date,'account_value':account_value_erl})

backtest_plot(account_value_erl_pd, 
             baseline_ticker = TICKER, 
             baseline_start = TEST_START_DATE,
             baseline_end = TEST_END_DATE)
# Out:
# ['/home/pop/.local/lib/python3.8/site-packages/ray/thirdparty_files', '/home/pop/.local/lib/python3.8/site-packages/ray/pickle5_files', '/home/pop/Documents/Code/RTML/Project/finRL/FinRL-Meta', '', '/home/pop/conda/lib/python3.8/site-packages', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '/home/pop/.local/lib/python3.8/site-packages', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/home/pop/.local/lib/python3.8/site-packages/IPython/extensions', '/home/pop/.ipython', '/home/pop/conda/lib/python3.8/site-packages', '/home/pop/conda/lib/python3.8/site-packages']
# ['BTCUSDT']
# ----------Training-----------------
# binance successfully connected
# 2021-09-01 2021-09-02
# 10
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# | Arguments Remove cwd: ./test_sac_el
# ################################################################################
# ID     Step    maxR |    avgR   stdR   avgS  stdS |    expR   objC   etc.
# 0  5.15e+03    1.00 |
# 0  5.15e+03    1.00 |    1.00    0.0    286     0 |    0.00   0.23   0.80   1.00
# 0  1.03e+04    1.00 |
# 0  1.03e+04    1.00 |    1.00    0.0    286     0 |    0.00   0.22   0.95   1.00
# 0  1.54e+04    1.00 |    1.00    0.0    286     0 |    0.00   0.22   1.18   1.00
# 0  2.06e+04    1.00 |    1.00    0.0    286     0 |    0.00   0.22   1.55   1.00
# 0  2.57e+04    1.00 |    1.00    0.0    286     0 |    0.00   0.20   2.20   1.00
# 0  3.09e+04    1.00 |    1.00    0.0    286     0 |    0.00   0.19   3.30   1.00
# 0  3.60e+04    1.00 |    1.00    0.0    286     0 |    0.00   0.17   5.14   1.00
# 0  4.12e+04    1.00 |    1.00    0.0    286     0 |    0.00   0.15   8.12   1.00
# 0  4.63e+04    1.00 |    1.00    0.0    286     0 |    0.00   0.16  12.99   1.00
# 0  5.15e+04    1.00 |    1.00    0.0    286     0 |   -0.00   0.21  20.39   0.99
# | UsedTime: 568 | SavedDir: ./test_sac_el
# | ReplayBuffer save in: ./test_sac_el/replay_0.npz
# ----------End Training-----------------
# ----------- Testing -----------------
# binance successfully connected
# 2021-09-21 2021-09-30
# 10
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# price_array:  1998
# /home/pop/Documents/Code/RTML/Project/finRL/FinRL-Meta/agents/elegantrl_models.py:111: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   s_tensor = _torch.as_tensor((state,), device=device)
# Test Finished!
# episode_return 1.0
# --------- End Testing ------------------
# binance successfully connected
# Using cached file ./cache/BTCUSDT_binance_2021-09-21_2021-09-30_5m.pickle
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# binance successfully connected
# Using cached file ./cache/BTCUSDT_binance_2021-09-21_2021-09-30_5m.pickle
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# /home/pop/.local/lib/python3.8/site-packages/empyrical/stats.py:710: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(
# /home/pop/.local/lib/python3.8/site-packages/empyrical/stats.py:799: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(average_annual_return, annualized_downside_risk, out=out)
# /home/pop/.local/lib/python3.8/site-packages/empyrical/stats.py:1527: RuntimeWarning: invalid value encountered in double_scalars
#   return np.abs(np.percentile(returns, 95)) / \
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-09-21</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-09-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>95</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>0.0%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.00</td>
#       <td>2021-09-21</td>
#       <td>2021-09-21</td>
#       <td>2021-09-21</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.00%</td>
#       <td>0.00%</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>
